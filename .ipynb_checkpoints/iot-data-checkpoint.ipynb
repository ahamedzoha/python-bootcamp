# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
with open('iot-001-241915-export.json') as f:
    d = json.load(f)

# %%
nd = json_normalize(d['devices-telemetry']['esp32_D05D44'])
# Out:
#   File "<ipython-input-23-e969ff53f57a>", line 1
#     nd = json_normalize(d['devices-telemetry']['esp32_D05D44'][])
#                                                                ^
# SyntaxError: invalid syntax

# %%
nd
# Out:
#    -Lg3ot70gf93wvy8CmEu.humidity  ... -Lz_IpVvls0cw5j6Oo4H.timestamp
# 0                             76  ...       2020-01-27T04:42:59.593Z
#
# [1 rows x 54435 columns]

# %%
d
# Out:
# {'devices-ids': {'esp32_D05D44': 'indoor'},
#  'devices-telemetry': {'esp32_D05D44': {'-Lg3ot70gf93wvy8CmEu': {'humidity': 76,
#     'temperature': '32.4',
#     'timestamp': '2019-05-29T18:21:42.166Z'},
#    '-Lg3p2vlksJu-TlslsxW': {'humidity': 76,
#     'temperature': '32.4',
#     'timestamp': '2019-05-29T18:21:57.153Z'},
#    '-Lg3p2vpY5djsg8buwkV': {'humidity': 76,
#     'temperature': '32.3',
#     'timestamp': '2019-05-29T18:21:52.160Z'},
#    '-Lg3p309F2DN6LI_4Drb': {'humidity': 76,
#     'temperature': '32.3',
#     'timestamp': '2019-05-29T18:22:02.163Z'},
#    '-Lg3p30P5xE4FcM_vf4x': {'humidity': 76,
#     'temperature': '32.4',
#     'timestamp': '2019-05-29T18:22:07.157Z'},
#    '-Lg3p30VhvfD6SaczROD': {'humidity': 76,
#     'temperature': '32.3',
#     'timestamp': '2019-05-29T18:22:12.163Z'},
#    '-Lg3p30eCHigeb5Upmcz': {'humidity': 76,
#     'temperature': '32.3',
#     'timestamp': '2019-05-29T18:22:17.162Z'},
#    '-Lg3p30nA6UTckJJ9SDR': {'humidity': 76,
# ...
