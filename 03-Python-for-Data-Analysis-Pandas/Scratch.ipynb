# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('dse_2017.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139745 entries, 0 to 139744
# Data columns (total 11 columns):
# date                        139745 non-null object
# trading_code                139745 non-null object
# last_traded_price           139745 non-null float64
# high                        139745 non-null float64
# low                         139745 non-null float64
# opening_price               139745 non-null float64
# closing_price               139745 non-null float64
# yesterdays_closing_price    139745 non-null float64
# trade                       139745 non-null int64
# value_mn                    139745 non-null float64
# volume                      139745 non-null int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.7+ MB

# %%
data.head(10)
# Out:
#                   date trading_code  last_traded_price  high  low  \
# 0  2017-12-28 00:00:00    1JANATAMF                6.4   6.5  6.4
# 1  2017-12-27 00:00:00    1JANATAMF                6.5   6.5  6.4
# 2  2017-12-26 00:00:00    1JANATAMF                6.5   6.6  6.4
# 3  2017-12-24 00:00:00    1JANATAMF                6.6   6.6  6.4
# 4  2017-12-21 00:00:00    1JANATAMF                6.6   6.6  6.4
# 5  2017-12-20 00:00:00    1JANATAMF                6.4   6.5  6.4
# 6  2017-12-19 00:00:00    1JANATAMF                6.4   6.6  6.4
# 7  2017-12-18 00:00:00    1JANATAMF                6.4   6.5  6.4
# 8  2017-12-17 00:00:00    1JANATAMF                6.5   6.5  6.4
# 9  2017-12-14 00:00:00    1JANATAMF                6.5   6.6  6.5
#
#    opening_price  closing_price  yesterdays_closing_price  trade  value_mn  \
# 0            6.4            6.4                       6.5     79     1.888
# 1            6.5            6.5                       6.5     73     1.295
# ...

# %%
sample = data.sample(5)

# %%
sample
# Out:
#                        date trading_code  last_traded_price   high    low  \
# 136398  2017-06-29 00:00:00    UNITEDFIN               21.4   22.0   21.3
# 124525  2017-05-14 00:00:00      T5Y0415                0.0    0.0    0.0
# 19289   2017-11-22 00:00:00          DBH              133.9  133.9  131.1
# 52955   2017-08-24 00:00:00          NBL               12.3   12.3   12.1
# 63447   2017-12-14 00:00:00    PRIMELIFE               58.0   58.6   56.4
#
#         opening_price  closing_price  yesterdays_closing_price  trade  \
# 136398           21.9           21.4                      21.7    156
# 124525            0.0            0.0                  100000.0      0
# 19289           133.1          132.5                     132.7    266
# 52955            12.3           12.2                      12.2   1021
# 63447            56.4           58.0                      56.4    256
#
#         value_mn   volume
# 136398     7.899   366468
# 124525     0.000        0
# ...

# %%
datx = sns.load_dataset('tips')
datx
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(datx, hue='sex', palette='coolwarm')
